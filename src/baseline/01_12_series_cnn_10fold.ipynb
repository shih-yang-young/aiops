# %%
import pandas as pd
data_path = "../../data/open_source_8454_combine_short_description.csv"
df = pd.read_csv(data_path)
# df_label_0 = df[df["Label"] == 0]
# df_label_0_to_drop = df_label_0.sample(n=3000, random_state=42)
# df = df.drop(df_label_0_to_drop.index)
df
# Out:
#                                         Inbound Message  Label
# 0     login issue verified user details employee man...      0
# 1     outlook hello team meetings skype meetings etc...      0
# 2                      cant log vpn cannot log vpn best      0
# 3       unable access tool page unable access tool page      0
# 4                               skype error skype error      0
# ...                                                 ...    ...
# 8449  emails coming mail good afternoon receiving em...     22
# 8450  telephony software issue telephony software issue      0
# 8451  vip windows password reset tifpdchb pedxruyf v...      0
# 8452  machine est funcionando unable access machine ...     44
# 8453  mehreren lassen sich verschiedene prgramdntyme...     49
#
# [8454 rows x 2 columns]

# %%
import sys
import os
sys.path.append(os.path.abspath('../ml_lib'))

from config import *
from experiment import run_kfold_experiment

# %%
messages, labels = df['Inbound Message'].tolist(), df['Label'].tolist()

# %%
model_list = ["bert-base-uncased", "roberta-base", "microsoft/deberta-base"]
hybrid_list = ["cnn1filter234drop3", "cnn1filter234drop5", "cnn1filter345drop3", "cnn1filter345drop5", "cnn2filter234drop3", "cnn2filter234drop5", "cnn2filter345drop3", "cnn2filter345drop5"]
resample_list = ["none"]

all_experiment_result = {}

for model_name in model_list:
    for hybrid_type in hybrid_list:
        for resample_method in resample_list:
            results = run_kfold_experiment(
                X=messages, y=labels, model_name=model_name, hybrid_type=hybrid_type, resample_method=resample_method,
                kfold=KFOLD_SPLIT, seed=SEED, epochs=EPOCHS, patience=PATIENCE, max_length=MAX_LENGTH, 
                batch_size=BATCH_SIZE, lr=LR, weight_decay=WEIGHT_DECAY
            )

            key = f"{model_name} {hybrid_type if hybrid_type else 'None'} {resample_method}"
            all_experiment_result[key] = results
# Out:
# ▶ Running: bert-base-uncased + cnn2filter345drop3 + none
# tokenizer is bert-base-uncased
# Using device: cuda
# CUDA Available: True
# CUDA Device: NVIDIA GeForce RTX 3050 6GB Laptop GPU
# Current GPU Memory Allocated: 2.97 GB
# Current GPU Memory Cached: 3.29 GB
#
# [Fold 1]
# Label distribution after resampling:
#   label 0: 3179
#   label 1: 25
#   label 2: 112
#   label 3: 24
#   label 4: 205
#   label 5: 116
#   label 6: 95
#   label 7: 31
#   label 8: 68
#   label 9: 65
#   label 10: 70
#   label 11: 172
#   label 12: 193
#   label 13: 29
#   label 14: 23
#   label 15: 25
#   label 16: 20
#   label 17: 231
#   label 18: 93
#   label 19: 45
#   label 20: 14
#   label 21: 35
#   label 22: 78
#   label 23: 160
#   label 24: 16
#   label 25: 50
#   label 26: 86
#   label 27: 49
#   label 28: 12
#   label 29: 13
#   label 30: 15
#   label 31: 80
#   label 32: 36
#   label 33: 32
#   label 34: 30
#   label 35: 12
#   label 36: 28
#   label 37: 21
#   label 38: 6
#   label 39: 103
#   label 40: 12
#   label 41: 8
#   label 42: 147
#   label 43: 16
#   label 44: 20
#   label 45: 9
#   label 46: 54
#   label 47: 529
#   label 48: 202
#   label 49: 69
# model is bert-base-uncased cnn2filter345drop3
# Epoch 1/20
#   1%|          | 4/423 [00:06<10:49,  1.55s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 10
#       8 for hybrid_type in hybrid_list:
#       9     for resample_method in resample_list:
# ---> 10         results = run_kfold_experiment(
#      11             X=messages, y=labels, model_name=model_name, hybrid_type=hybrid_type, resample_method=resample_method,
#      12             kfold=KFOLD_SPLIT, seed=SEED, epochs=EPOCHS, patience=PATIENCE, max_length=MAX_LENGTH,
#      13             batch_size=BATCH_SIZE, lr=LR, weight_decay=WEIGHT_DECAY
#      14         )
#      16         key = f"{model_name} {hybrid_type if hybrid_type else 'None'} {resample_method}"
#      17         all_experiment_result[key] = results
#
# File ~\Jupyter\aiops\src\ml_lib\experiment.py:157, in run_kfold_experiment(X, y, model_name, hybrid_type, resample_method, kfold, seed, epochs, patience, max_length, batch_size, lr, weight_decay)
#     155 for epoch in range(epochs):
#     156     print(f"Epoch {epoch + 1}/{epochs}")
# --> 157     train_loss = train_epoch(model, train_loader, optimizer, criterion, device)
#     158     metrics = eval_model(model, val_loader, criterion, device, num_labels)
#     159     metrics["train_loss"] = train_loss
#
# File ~\Jupyter\aiops\src\ml_lib\train_eval.py:18, in train_epoch(model, dataloader, optimizer, criterion, device)
#      16 outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
#      17 loss = outputs["loss"]
# ---> 18 total_loss += loss.item()
#      19 loss.backward()
#      20 optimizer.step()
#
# KeyboardInterrupt:

# %%
all_experiment_result
